# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import gmaps

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
new = pd.read_csv("../starter_code/new_cities.csv")

# %%
new
# Out:
#      city_id            city      lat       lng  Max Temp  Humidity  \
# 0          0     yellowknife  62.4560 -114.3525     30.99        54
# 1          1         mataura -46.1927  168.8643     48.99        83
# 2          2        hamilton  39.1834  -84.5333     71.01        32
# 3          3         camacha  33.0833  -16.3333     60.80        67
# 4          4          atuona  -9.8000 -139.0333     79.02        70
# ..       ...             ...      ...       ...       ...       ...
# 563      563        goderich  43.7501  -81.7165     51.80        46
# 564      564         machico  32.7000  -16.7667     62.60        67
# 565      565         ternate   0.8000  127.4000     80.24        78
# 566      566  vestmannaeyjar  63.4427  -20.2734     40.53        62
# 567      567         turangi -39.0000  175.9333     47.08        37
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        8.05      CA  1619902031
# 1            17        3.00      NZ  1619902179
# 2             1       12.66      US  1619901964
# 3            20        5.75      PT  1619902180
# 4             2        6.31      PF  1619902116
# ..          ...         ...     ...         ...
# 563         100       19.57      CA  1619902677
# 564          40        9.22      PT  1619902677
# 565          96        4.56      ID  1619902678
# 566         100       14.36      IS  1619902678
# 567           5        0.09      NZ  1619902678
#
# [568 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
new["Humidity"]
# Out:
# 0      54
# 1      83
# 2      32
# 3      67
# 4      70
#        ..
# 563    46
# 564    67
# 565    78
# 566    62
# 567    37
# Name: Humidity, Length: 568, dtype: int64

# %%
 # Store 'Lat' and 'Lng' into  locations 
clouds = new.dropna()
locations = clouds[["lat", "lng"]].astype(float)


humidity_rate = clouds["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity_rate, 
                                 dissipating=False, max_intensity=10,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# A max temperature lower than 80 degrees but higher than 70.
#
#
# Wind speed less than 10 mph.
#
#
# Zero cloudiness.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
loc.clouds.df("weather"<80)

# %%
hotel_df = clouds.loc[(clouds["Max Temp"]<80)&(clouds["Max Temp"]>70)&(clouds["Wind Speed"]<10)&(clouds["Cloudiness"]==0)]
hotel_df
# Out:
#      city_id            city      lat      lng  Max Temp  Humidity  \
# 19        19  saint-philippe -21.3585  55.7679     75.20        69
# 67        67           pisco -13.7000 -76.2167     73.40        64
# 189      189         sakakah  29.9697  40.2064     77.00        11
# 208      208           moron -34.6534 -58.6198     77.00        44
# 214      214          lipari  38.4674  14.9540     72.00        53
# 301      301        belgrade  44.8040  20.4651     73.00        52
# 327      327    saint-pierre -21.3393  55.4781     75.20        69
# 331      331       concordia -31.3930 -58.0209     78.80        44
# 441      441         ardakan  32.3100  54.0175     73.40        33
# 461      461         le port -20.9373  55.2919     75.20        78
# 489      489            tura  25.5198  90.2201     70.74        73
#
#      Cloudiness  Wind Speed Country        Date
# 19            0        6.91      RE  1619902515
# 67            0        9.22      PE  1619902489
# 189           0        6.91      SA  1619902564
# 208           0        9.22      AR  1619902518
# 214           0        6.91      IT  1619902571
# 301           0        9.22      RS  1619902453
# 327           0        6.91      RE  1619902607
# 331           0        6.91      AR  1619902608
# 441           0        9.22      IR  1619902641
# 461           0        3.44      RE  1619902647
# 489           0        4.25      IN  1619902655

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"]=""
hotel_df
# Out:
# <ipython-input-13-4b7c85aad61d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"]=""
#      city_id            city      lat      lng  Max Temp  Humidity  \
# 19        19  saint-philippe -21.3585  55.7679     75.20        69
# 67        67           pisco -13.7000 -76.2167     73.40        64
# 189      189         sakakah  29.9697  40.2064     77.00        11
# 208      208           moron -34.6534 -58.6198     77.00        44
# 214      214          lipari  38.4674  14.9540     72.00        53
# 301      301        belgrade  44.8040  20.4651     73.00        52
# 327      327    saint-pierre -21.3393  55.4781     75.20        69
# 331      331       concordia -31.3930 -58.0209     78.80        44
# 441      441         ardakan  32.3100  54.0175     73.40        33
# 461      461         le port -20.9373  55.2919     75.20        78
# 489      489            tura  25.5198  90.2201     70.74        73
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 19            0        6.91      RE  1619902515
# 67            0        9.22      PE  1619902489
# 189           0        6.91      SA  1619902564
# 208           0        9.22      AR  1619902518
# 214           0        6.91      IT  1619902571
# 301           0        9.22      RS  1619902453
# 327           0        6.91      RE  1619902607
# 331           0        6.91      AR  1619902608
# 441           0        9.22      IR  1619902641
# 461           0        3.44      RE  1619902647
# 489           0        4.25      IN  1619902655

# %%
params = {"key":g_key,
         "radius":5000,
         "type": "lodging"}
for idx,row in hotel_df.iterrows():
    lt = row["lat"]
    lg = row["lng"]
    params["location"]=f"{lt},{lg}"
    resp=requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json",params=params).json()
    try:
        hotel_df.loc[idx,"Hotel Name"]=resp["results"][0]["name"]
    except:
        print("hotel not found")
        
hotel_df
# Out:
# C:\Users\Frank\anaconda\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#      city_id            city      lat      lng  Max Temp  Humidity  \
# 19        19  saint-philippe -21.3585  55.7679     75.20        69
# 67        67           pisco -13.7000 -76.2167     73.40        64
# 189      189         sakakah  29.9697  40.2064     77.00        11
# 208      208           moron -34.6534 -58.6198     77.00        44
# 214      214          lipari  38.4674  14.9540     72.00        53
# 301      301        belgrade  44.8040  20.4651     73.00        52
# 327      327    saint-pierre -21.3393  55.4781     75.20        69
# 331      331       concordia -31.3930 -58.0209     78.80        44
# 441      441         ardakan  32.3100  54.0175     73.40        33
# 461      461         le port -20.9373  55.2919     75.20        78
# 489      489            tura  25.5198  90.2201     70.74        73
#
#      Cloudiness  Wind Speed Country        Date  \
# 19            0        6.91      RE  1619902515
# 67            0        9.22      PE  1619902489
# 189           0        6.91      SA  1619902564
# 208           0        9.22      AR  1619902518
# 214           0        6.91      IT  1619902571
# 301           0        9.22      RS  1619902453
# 327           0        6.91      RE  1619902607
# 331           0        6.91      AR  1619902608
# 441           0        9.22      IR  1619902641
# 461           0        3.44      RE  1619902647
# 489           0        4.25      IN  1619902655
#
#                                         Hotel Name
# 19                    Chambres d'hôte "La Trinité"
# 67                        Hotel San Isidro Oficial
# 189                  Fakhamat Al Orjoana Apartment
# 208                                    Hotel Morón
# 214  Hotel Villa Diana Soc. Clelia Hunziker s.a.s.
# 301          Saruna Wellness - Hotel Park Belgrade
# 327                                  Lindsey Hôtel
# 331                            Palmar Hotel Casino
# 441                                  Ardakan Hotel
# 461                              KORBEY D'OR OUEST
# 489                       Hotel RIKMAN Continental

# %%
params = {"key":g_key,
         "rankby":"distance",
         "type": "lodging",
         "location":"-34.6534,-58.6198"}
requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json",params=params).json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwIhepCM0Odl6-a0aKqm-8M5DH8sNqLCpWGEYJ8VV_rzHMicvqc-rrl1c0Pi51iUbxTop0vn7CcJh-vFPNL4rkJKGaoBERYBq_UHfHIVUwUMewwRc3PwXMNfORG8S5Wk_gnSDJNLUs1PBemn_CHqhKnjOhfadXcRrDQDDyK0qVI8uDMxgerOPOqZQ1fVCZIYky5IqR7FQHEJBd7dbEIds3CTL8msPbRwxnB8ftfDTW65RdHBN5mUBPYKTdIk8VJCBQyihPysphG2aKM7QkH5bTdcp7pVXFJBu7jePZEqn_Wz74cVDYSiQwGwBjz6uSrSqgu0EQud_zy0Cry1v3EnxuWy5rUXwdTz4ygfCkwtAae8rERxQOLQ9cTmmlAyjmjZ0_gtg6NCytRfMoRt9NVt7fsPisIS2CYvsTfMIzzVkp9U_9OgpteJif59nEk',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.65301669999999,
#      'lng': -58.61926130000001},
#     'viewport': {'northeast': {'lat': -34.65166181970849,
#       'lng': -58.61791231970849},
#      'southwest': {'lat': -34.65435978029149, 'lng': -58.62061028029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Estacionamiento ANTONIO',
#    'place_id': 'ChIJa5M-9mbHvJUR0Hg44wVeru4',
#    'plus_code': {'compound_code': '89WJ+Q7 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389WJ+Q7'},
#    'rating': 2.5,
#    'reference': 'ChIJa5M-9mbHvJUR0Hg44wVeru4',
#    'scope': 'GOOGLE',
#    'types': ['rv_park', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'B1708EAN, General Bartolomé Mitre 742, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6535995, 'lng': -58.6207332},
#     'viewport': {'northeast': {'lat': -34.6522423697085,
#       'lng': -58.61894006970849},
#      'southwest': {'lat': -34.6549403302915, 'lng': -58.62163803029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torre del Madero',
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117086284929704425724">Sonia Arévalo</a>'],
#      'photo_reference': 'ATtYBwJyLY46wYZUqvHK1STCGhF1yLk__J4yZyb6WqJB2uL1leaMZXtvrK_LT0nYmAmDj4jOjjw0mK6sRhKDLLwFH0Rss_9aF6IwJEDUIRZuukuPuEPMQw3gOy2qwdRKDhUOMjSFMQBYpDa8p-9QesbkK1XAGJSuRqdOwQVIeSJEeUZUop4v',
#      'width': 600}],
#    'place_id': 'ChIJP4-SGFnHvJURAL5btm-3EPY',
#    'plus_code': {'compound_code': '89WH+HP Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389WH+HP'},
#    'rating': 4,
#    'reference': 'ChIJP4-SGFnHvJURAL5btm-3EPY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '25 de Mayo 473, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.651774, 'lng': -58.62205420000001},
#     'viewport': {'northeast': {'lat': -34.6503647197085,
#       'lng': -58.62070221970849},
#      'southwest': {'lat': -34.6530626802915, 'lng': -58.6234001802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torre de la Catedral',
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117086284929704425724">Sonia Arévalo</a>'],
#      'photo_reference': 'ATtYBwK33BeRVNrD2_r7nsrHk-fARtS2yQaj4wMDWEw92pGUehSfUZLlUGziNhzKdWCfkqDeJm89_i1OrsQg3LW1muZCHFUV0cf_Qy1VBSZrnSekvnr-NtVaELpOPndwg3VmVm2Lsxvn8NCEaMDVTCCmiWAiTOwLCoskThntmkP87DGOD3PM',
#      'width': 600}],
#    'place_id': 'ChIJQSBJJQ3HvJUR3IXTNs-f-_Q',
#    'plus_code': {'compound_code': '89XH+75 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XH+75'},
#    'rating': 5,
#    'reference': 'ChIJQSBJJQ3HvJUR3IXTNs-f-_Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Nuestra Señora del Buen Viaje 954, ECR'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6505673, 'lng': -58.6191972},
#     'viewport': {'northeast': {'lat': -34.6492038697085,
#       'lng': -58.61784751970849},
#      'southwest': {'lat': -34.6519018302915, 'lng': -58.6205454802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Comarca Center',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJA5NQowLHvJURYDXPveVGeNU',
#    'plus_code': {'compound_code': '89XJ+Q8 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XJ+Q8'},
#    'reference': 'ChIJA5NQowLHvJURYDXPveVGeNU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Almirante Guillermo Brown 754, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.65054860000001, 'lng': -58.6192012},
#     'viewport': {'northeast': {'lat': -34.64920376970851,
#       'lng': -58.61785241970848},
#      'southwest': {'lat': -34.65190173029151, 'lng': -58.6205503802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Comarca Center Alojamiento temporario 4 personas',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJOT66WfXHvJURVTO9dylzPbM',
#    'plus_code': {'compound_code': '89XJ+Q8 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XJ+Q8'},
#    'reference': 'ChIJOT66WfXHvJURVTO9dylzPbM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Almirante Guillermo Brown 754, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6524945, 'lng': -58.61641539999999},
#     'viewport': {'northeast': {'lat': -34.6511458197085,
#       'lng': -58.61499461970849},
#      'southwest': {'lat': -34.6538437802915, 'lng': -58.6176925802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel morón',
#    'place_id': 'ChIJUR44XMXHvJURdk_7FiFStio',
#    'plus_code': {'compound_code': '89XM+2C Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XM+2C'},
#    'rating': 2.7,
#    'reference': 'ChIJUR44XMXHvJURdk_7FiFStio',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Ingeniero Ernesto C. Boatti 361, JGG'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6544385, 'lng': -58.61644810000001},
#     'viewport': {'northeast': {'lat': -34.6530913197085,
#       'lng': -58.6150342697085},
#      'southwest': {'lat': -34.6557892802915, 'lng': -58.6177322302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torre del Alto',
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117086284929704425724">Sonia Arévalo</a>'],
#      'photo_reference': 'ATtYBwIlEFFXIxgrCeeJ1FrOBbIf70upjb-m5K3hl-g5bzSs2q4NfPPIOr3v6YgpdXQe0B2rMh-psxu4SZX4KgapAI_hDfdH4kUkrMEGRgbo7q69JyNTiTw-4oyMmC13CdXp8rph0wRp6z8x5PaJtfjX786XPQrA6kYvrzqqCljCwYUE_n_F',
#      'width': 600}],
#    'place_id': 'ChIJz-5z0t7HvJURJMt8-zkObYo',
#    'plus_code': {'compound_code': '89WM+6C Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389WM+6C'},
#    'rating': 5,
#    'reference': 'ChIJz-5z0t7HvJURJMt8-zkObYo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'JGK, Ingeniero Ernesto C. Boatti 555, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6553686, 'lng': -58.62285989999999},
#     'viewport': {'northeast': {'lat': -34.65401946970849,
#       'lng': -58.62145891970849},
#      'southwest': {'lat': -34.65671743029149, 'lng': -58.62415688029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torres Sport',
#    'photos': [{'height': 4096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106959557679693796910">Fabiana Quintero</a>'],
#      'photo_reference': 'ATtYBwJewdx_ieWa3YcLADB8zxv6_NJyfiOBNVLOtBcnXU2GFjPL3SRLJAamoc-i1SHPnkVRZWdPSZOLZcxl42hbSLusDtQ8s56TBTMvUTpLm3-jtT0qzwi3wRFhR4_xpMRKWrXjO7N-aNJe2QDMcQniJRTjEFLoqWSNfoQ5BiUGizSpPQpo',
#      'width': 2304}],
#    'place_id': 'ChIJhX8C9WfHvJURdy_JIjM4UQU',
#    'plus_code': {'compound_code': '89VG+VV Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389VG+VV'},
#    'rating': 3,
#    'reference': 'ChIJhX8C9WfHvJURdy_JIjM4UQU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'IHM, General José de San Martín 659, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6504842, 'lng': -58.6176981},
#     'viewport': {'northeast': {'lat': -34.6491862697085,
#       'lng': -58.6163530697085},
#      'southwest': {'lat': -34.6518842302915, 'lng': -58.61905103029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torre del Abra',
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117086284929704425724">Sonia Arévalo</a>'],
#      'photo_reference': 'ATtYBwLhpXQaSVWnbm43D9GcZ-6r4ZG-nBunh9fIS8JCNXMSiMws1ETUL-QqWxPPIisa6WdLGZmUorPtkrZPWmuRWmgnpS_MhMmZD9Xcry_gCDYoF_RUbpwu4VSmZNdXOuWQOFCDc1A8UVhwRr191RjIiYI6xiNOvVHtYpk_7HW5AlFKzfjm',
#      'width': 600}],
#    'place_id': 'ChIJacwq-JjHvJUR-_xbHLYvRmM',
#    'plus_code': {'compound_code': '89XJ+RW Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XJ+RW'},
#    'rating': 5,
#    'reference': 'ChIJacwq-JjHvJUR-_xbHLYvRmM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Almirante Guillermo Brown 623, EFL'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6558611, 'lng': -58.6167212},
#     'viewport': {'northeast': {'lat': -34.65447656970849,
#       'lng': -58.6153733197085},
#      'southwest': {'lat': -34.65717453029149, 'lng': -58.61807128029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Negra Montaña Fresca',
#    'place_id': 'ChIJkVKyEUPHvJUR74YETjhhkEA',
#    'plus_code': {'compound_code': '89VM+M8 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389VM+M8'},
#    'reference': 'ChIJkVKyEUPHvJUR74YETjhhkEA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'casa Nro. P, General Juan José Valle, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6511415, 'lng': -58.61633320000001},
#     'viewport': {'northeast': {'lat': -34.64979501970851,
#       'lng': -58.6149300197085},
#      'southwest': {'lat': -34.6524929802915, 'lng': -58.6176279802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Nuevo Ostende',
#    'place_id': 'ChIJqTWvPWTHvJUROsF7aotApWg',
#    'plus_code': {'compound_code': '89XM+GF Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XM+GF'},
#    'reference': 'ChIJqTWvPWTHvJUROsF7aotApWg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Ingeniero Ernesto C. Boatti 239, JGE'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.65003850000001, 'lng': -58.6171923},
#     'viewport': {'northeast': {'lat': -34.64868911970851,
#       'lng': -58.6159138197085},
#      'southwest': {'lat': -34.6513870802915, 'lng': -58.61861178029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Torre Oriental',
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117086284929704425724">Sonia Arévalo</a>'],
#      'photo_reference': 'ATtYBwI_0suHLzuG3Zt4RmwoK4mrp3dYXqE6mjaZIv7DvP4vNQ6sCb7vIA_amtJtOf3ajE2GIMLzoU3G-QXvUatIPL5dBSmXlmLzTdAW9w1rjwSdOiWT3c6pRqQUL947dUXHdVrnwOQEojXCHG3fgIkjIfOU4UC6M7NTSHwo8ZoHq-JIf5oM',
#      'width': 600}],
#    'place_id': 'ChIJufRPDGDHvJURpWdEm3Q2LvU',
#    'plus_code': {'compound_code': '89XM+X4 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XM+X4'},
#    'reference': 'ChIJufRPDGDHvJURpWdEm3Q2LvU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'República Oriental del Uruguay 160, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.650377, 'lng': -58.622991},
#     'viewport': {'northeast': {'lat': -34.6490614197085,
#       'lng': -58.62164371970849},
#      'southwest': {'lat': -34.65175938029149, 'lng': -58.62434168029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'AGENCIA',
#    'place_id': 'ChIJ-Q_bfkjHvJURZjfFw9FkY6k',
#    'plus_code': {'compound_code': '89XG+RR Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XG+RR'},
#    'reference': 'ChIJ-Q_bfkjHvJURZjfFw9FkY6k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Almirante Guillermo Brown 1017, EFT'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.649368, 'lng': -58.61771969999999},
#     'viewport': {'northeast': {'lat': -34.6479601697085,
#       'lng': -58.61636896970848},
#      'southwest': {'lat': -34.6506581302915, 'lng': -58.6190669302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'A ponerla',
#    'place_id': 'ChIJO40tTczHvJURKK3vgfdy38U',
#    'plus_code': {'compound_code': '992J+7W Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q3992J+7W'},
#    'rating': 5,
#    'reference': 'ChIJO40tTczHvJURKK3vgfdy38U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Avenida Rivadavia, Buenos Aires'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6579035, 'lng': -58.6188174},
#     'viewport': {'northeast': {'lat': -34.6565557697085,
#       'lng': -58.61737561970849},
#      'southwest': {'lat': -34.6592537302915, 'lng': -58.6200735802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Parra alma',
#    'place_id': 'ChIJiVoYDwXHvJURBjJbfQLxXYk',
#    'plus_code': {'compound_code': '89RJ+RF Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389RJ+RF'},
#    'reference': 'ChIJiVoYDwXHvJURBjJbfQLxXYk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9 de Julio 865, JDQ'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.64886389999999, 'lng': -58.6220285},
#     'viewport': {'northeast': {'lat': -34.6476678697085,
#       'lng': -58.6206709697085},
#      'southwest': {'lat': -34.6503658302915, 'lng': -58.62336893029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Colucci equipment | Suc. Hummock',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 958,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109642466117966517743">Colucci Equipamiento | Suc. Moron</a>'],
#      'photo_reference': 'ATtYBwJIK8ZbEkXh9jG1xgE_mM_LSBrjQbiLc6IPDykzAitLwXrkLoXpFSBhEDUixHUUfq4j50oJ9geqAVuRzNGi_Z27INPxGJhpQ3W0SBFkD25iPEbf0v900HRKnPF5u57YrLgj215PrNajRNCCZQpaVXgmT_1a0dn-KNvEa_nVaVunFCP7',
#      'width': 1280}],
#    'place_id': 'ChIJA7bChmDHvJURIFVe46gqbSU',
#    'plus_code': {'compound_code': '992H+F5 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q3992H+F5'},
#    'rating': 4.3,
#    'reference': 'ChIJA7bChmDHvJURIFVe46gqbSU',
#    'scope': 'GOOGLE',
#    'types': ['store',
#     'campground',
#     'lodging',
#     'home_goods_store',
#     'park',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 604,
#    'vicinity': 'Avenida Rivadavia 18355, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.648409, 'lng': -58.6167704},
#     'viewport': {'northeast': {'lat': -34.6470300197085,
#       'lng': -58.61542136970849},
#      'southwest': {'lat': -34.64972798029149, 'lng': -58.61811933029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel pensión florencia',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110342797872261501741">alexis el capo de merlo</a>'],
#      'photo_reference': 'ATtYBwI97zOCsfRZtQpPoipe7sxH5nacaMCl6iedxx88Xscd9AHvR6Zeoz9fiwhFs1SQB_Wt70LkQTU6TR2O4KK0A70fghQlT6Z2pX1rDV9p2AEYkbe6tzVR9mPqxOOWB9hVVf2RBhDwV75Hmyvv6Tthcxq9W0v1MGdUQMG3hpFKGIbTil1M',
#      'width': 3120}],
#    'place_id': 'ChIJQxrEEE3HvJURP8OyRku8Axw',
#    'plus_code': {'compound_code': '992M+J7 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q3992M+J7'},
#    'rating': 3.7,
#    'reference': 'ChIJQxrEEE3HvJURP8OyRku8Axw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Presidente Domingo Faustino Sarmiento 540, EKL'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6524596, 'lng': -58.62660709999999},
#     'viewport': {'northeast': {'lat': -34.65111176970851,
#       'lng': -58.62518106970849},
#      'southwest': {'lat': -34.65380973029151, 'lng': -58.6278790302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'KR',
#    'place_id': 'ChIJ3TFYLazHvJUR9coQIADyMy4',
#    'plus_code': {'compound_code': '89XF+29 Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389XF+29'},
#    'reference': 'ChIJ3TFYLazHvJUR9coQIADyMy4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'La Roche 375, IRD'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6483916, 'lng': -58.6154415},
#     'viewport': {'northeast': {'lat': -34.6469811697085,
#       'lng': -58.6140215697085},
#      'southwest': {'lat': -34.6496791302915, 'lng': -58.61671953029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel FRENCH',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1228,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109106940823453296143">Hotel FRENCH</a>'],
#      'photo_reference': 'ATtYBwKeXuWSC41qYb1IbCGadFWOYfe92T_oQVWxzH82qOyBA51AlFBON8t7XIliBlKjXpUVtFtgZIV-ZfHFxh7oTiKyE4ajiLMIJ_n41_RlFKC4h3h0_R2G6w3scbdN5nbU1Adc96a9P9JPDpJLjaiZ5yCMQckS9kf0iMm_Cq3HlqmxmA3K',
#      'width': 1132}],
#    'place_id': 'ChIJp1rwlmPHvJURhaV-TJglEOo',
#    'plus_code': {'compound_code': '992M+JR Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q3992M+JR'},
#    'rating': 3.7,
#    'reference': 'ChIJp1rwlmPHvJURhaV-TJglEOo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 176,
#    'vicinity': 'Domingo French 11, Morón'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -34.6602594, 'lng': -58.6213335},
#     'viewport': {'northeast': {'lat': -34.6589772197085,
#       'lng': -58.61998236970849},
#      'southwest': {'lat': -34.6616751802915, 'lng': -58.6226803302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'MASA LA MATANZA',
#    'place_id': 'ChIJIalCn-fHvJUReChku0DP8wM',
#    'plus_code': {'compound_code': '89QH+VF Morón, Buenos Aires Province, Argentina',
#     'global_code': '48Q389QH+VF'},
#    'reference': 'ChIJIalCn-fHvJUReChku0DP8wM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Avenida Hipólito Yrigoyen 899, DLI'}],
#  'status': 'OK'}

# %%
hotel_df["Hotel Name"].isna().sum()
# Out:
# 0

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["lat", "lng"]]
humidity_rate=clouds["Humidity"]
heat_locations = clouds[["lat", "lng"]].astype(float)

# %%
# Add marker layer ontop of heat map
fig=gmaps.figure()
heat_layer = gmaps.heatmap_layer(heat_locations, weights=humidity_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 5)

fig.add_layer(heat_layer)
ml = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(ml)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
